# %%
import pandas as pd
import numpy as np

try:
    import gensim
except:
    # !pip install gensim
    import gensim
    
try:
    import keras
except:
    # !pip install tensorflow
    # !pip install keras
    import keras
    
try:
    from sklearn.model_selection import train_test_split
except:
    # !pip install sklearn
    from sklearn.model_selection import train_test_split

try:
    import matplotlib.pyplot as plt
except:
    # !pip install matplotlib
    import matplotlib.pyplot as plt
    
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
def file_reader(file_location):
    if(file_location.endswith('csv')):
        return pd.read_csv( file_location , engine = 'python', index_col=0)
    elif (file_location.endswith('tsv')):
        return pd.read_csv( file_location , engine = 'python' ,sep = '\t')

# %%
def read_dataset( file_location ):
    df = file_reader(file_location)
    token_list  = []
    for i in range( len( df ) ):
        token_list.append( df['TEXT'][i].split() )
    df['TOKENS'] = token_list
    return df

# %%
def tokens_to_sequence( tokenizer , texts , max_length ):
    sequences   = tokenizer.texts_to_sequences( texts )
    padded_data = pad_sequences( sequences , maxlen=max_length , padding='post' )
    return padded_data
    
def tokenize_dataset(df, max_length):
    num_words   = len(sorted(set([word for tok in df['TOKENS'] for word in tok])))
    tokenizer   = Tokenizer( num_words=num_words, lower=True, char_level=False , oov_token = "<OOV>")
    tokenizer.fit_on_texts( df['TEXT'].tolist() )
    return (tokenizer, num_words)

def get_embeddings(word_index):
    word2vec_path = '0_additional_files\GoogleNews-vectors-negative300.bin'
    word2vec      = gensim.models.KeyedVectors.load_word2vec_format(word2vec_path, binary=True)
    embeddings = np.zeros( (len(word_index)+1, embedding_dim))
    for word,index in word_index.items():
        if word in word2vec :
            embeddings[index,:] = word2vec[word] 
    del word2vec
    return embeddings

def embedded_values(data, embeddings):
    emb = []
    for value in data:
        t = np.array( np.mean([embeddings[w] for w in value if w < len(embeddings)] or [np.zeros(300)], axis=0))
        emb.append(t)
    return np.array(emb)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import LeaveOneOut,KFold
from sklearn.model_selection import cross_val_score,cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import svm

# %%
inp = '3_data_preprocessed/'
trait_names = ['cEXT' , 'cNEU' , 'cAGR' , 'cCON' , 'cOPN']
sklearn_models = [
    svm.SVC(kernel='rbf', gamma = 1.0 , C = 10)
    #GaussianNB(priors=[0.5,0.5]),
    #LogisticRegression(),
    #RandomForestClassifier(max_depth=2, random_state=0)
]
max_length = 300
embedding_dim = 300

# %%
df_essay   = read_dataset( inp + 'essays.csv' )
num_words  = len(sorted(set([word for tok in df_essay['TOKENS'] for word in tok])))
tokenizer, num_words = tokenize_dataset(df_essay, max_length)
embeddings = get_embeddings(tokenizer.word_index)

# %%
essay_sequences  = tokens_to_sequence(tokenizer, df_essay['TEXT'], max_length)
X = embedded_values(essay_sequences, embeddings)

# %%
csval = {}

for model in sklearn_models:
    
    model_name = type(model).__name__
    csval[model_name] = {}
    print(model_name)
    
    for trait in trait_names:
        print('-----', trait, end = "  : ")
        
        y      = df_essay[trait]
        cv     = LeaveOneOut()
        scores = cross_validate(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1,return_train_score=True, verbose=10)
        csval[model_name][trait] = scores
        
        #print('    Accuracy: %.3f (%.3f)' % (np.mean(scores), np.std(scores)))
# Out:
# SVC
# ----- cEXT  :
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 24.2min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed: 25.5min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed: 28.0min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed: 29.3min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 30.6min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed: 32.0min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed: 33.4min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 34.8min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed: 36.2min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 37.7min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed: 39.2min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed: 40.7min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed: 42.3min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 43.9min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 45.5min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 47.2min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 48.9min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 50.6min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 52.4min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 54.1min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 56.0min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 57.8min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 59.7min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 61.6min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 63.5min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 65.4min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 67.4min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 69.4min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 71.5min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 73.6min
# [Parallel(n_jobs=-1)]: Done 2468 out of 2468 | elapsed: 74.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ----- cNEU  :
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 21.2min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 22.4min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 23.6min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed: 24.8min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed: 26.0min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed: 27.3min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed: 28.5min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed: 31.2min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed: 32.6min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed: 35.5min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 36.9min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed: 38.4min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed: 40.0min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed: 41.5min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 43.1min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 44.7min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 46.4min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 48.1min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 49.7min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 51.5min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 53.3min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 55.1min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 56.9min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 58.7min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 60.6min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 62.5min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 64.4min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 66.4min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 68.4min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 70.5min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 72.6min
# [Parallel(n_jobs=-1)]: Done 2468 out of 2468 | elapsed: 73.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ----- cAGR  :
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 23.9min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed: 26.4min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed: 27.7min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 30.3min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed: 31.6min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 34.5min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed: 35.9min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 37.4min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed: 38.9min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed: 40.4min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed: 42.0min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 43.6min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 45.2min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 46.9min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 48.6min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 50.3min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 52.0min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 53.8min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 55.6min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 57.4min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 59.3min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 61.2min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 63.1min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 65.1min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 67.0min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 69.1min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 71.1min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 73.1min
# [Parallel(n_jobs=-1)]: Done 2468 out of 2468 | elapsed: 73.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ----- cCON  :
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 20.3min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 23.7min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed: 26.2min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed: 27.4min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed: 28.7min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 30.0min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed: 31.4min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed: 32.8min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 34.2min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed: 35.6min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 37.0min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed: 38.5min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed: 40.0min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed: 41.6min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 43.1min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 44.8min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 46.4min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 48.0min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 49.7min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 51.5min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 53.2min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 55.0min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 56.8min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 58.7min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 60.5min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 62.5min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 64.3min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 66.3min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 68.3min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 70.3min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 72.4min
# [Parallel(n_jobs=-1)]: Done 2468 out of 2468 | elapsed: 73.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ----- cOPN  :
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed: 20.3min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed: 21.3min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 22.4min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed: 23.6min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed: 27.1min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 28.4min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed: 29.6min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed: 30.9min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 32.2min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed: 36.4min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed: 37.8min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed: 39.3min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 40.8min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 42.4min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 43.9min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 45.5min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 47.1min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 48.8min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 50.4min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 52.2min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 53.9min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 55.6min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 57.4min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 59.2min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 61.1min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 63.0min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 64.9min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 66.9min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 68.8min
# [Parallel(n_jobs=-1)]: Done 2468 out of 2468 | elapsed: 69.5min finished

# %%
accuracies = {}
for model in sklearn_models:
    model_name = type(model).__name__
    accuracies[model_name] = {}
    print(model_name)
    for trait in trait_names:
        accuracies[model_name][trait] = {}
        accuracies[model_name][trait]['train_score'] = np.mean( csval[model_name][trait]['train_score'] )
        accuracies[model_name][trait]['test_score']  = np.mean( csval[model_name][trait]['test_score'] )
# Out:
# SVC

# %%
import json

with open("Cross Validation/acc_s.json", 'w') as fp:
    json.dump(accuracies, fp)

# %%
import pickle
with open('Cross Validation/data_s', 'wb') as fp:
    pickle.dump(csval, fp, protocol=pickle.HIGHEST_PROTOCOL)
